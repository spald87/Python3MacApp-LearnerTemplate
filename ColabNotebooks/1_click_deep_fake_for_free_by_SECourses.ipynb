# %% [markdown]
# <a href="https://colab.research.google.com/github/spald87/Python3MacApp-LearnerTemplate/blob/main/ColabNotebooks/1_click_deep_fake_for_free_by_SECourses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Updated 29 August 2025 Fully Working again
# ### Someone upgraded to Gold Tier and I fixed all issues : https://www.patreon.com/c/SECourses
# ## Most Advanced DeepFake FaceFusion for Windows, RunPod and Massed Compute : https://www.patreon.com/posts/103765029
# ## Very Advanced VisoMaster for Windows and Massed Compute : https://www.patreon.com/posts/121570322
# ## Deep Live Cam for Windows : https://www.patreon.com/posts/125826778

# %%
# !git clone https://github.com/FurkanGozukara/rop_fixed roop
# %cd roop
# !git clone https://github.com/FurkanGozukara/BasicSR
# !pip install -r a.txt
# !pip uninstall basicsr --yes

# %cd /content/roop/BasicSR
# !pip install -e .

import sys
import os
import importlib.util

# Define the name of the module we want to patch
module_name = "opennsfw2._inference"

try:
    # Find the specification for the module
    spec = importlib.util.find_spec(module_name)
    if spec is None or spec.origin is None:
        print(f"Error: Could not find the module '{module_name}'. Is opennsfw2 installed?")
    else:
        file_path = spec.origin
        print(f"Found file to patch at: {file_path}")

        # Read the original file content
        with open(file_path, 'r') as f:
            lines = f.readlines()

        # Write the patched content back to the file
        patched = False
        with open(file_path, 'w') as f:
            for line in lines:
                # Find the problematic line and comment it out
                if "cv2.destroyAllWindows()" in line:
                    f.write("#" + line) # Comment out the line
                    patched = True
                    print("Found and patched the problematic line.")
                else:
                    f.write(line)

        if patched:
            print("Patch applied successfully!")
        else:
            print("Warning: The line 'cv2.destroyAllWindows()' was not found. The file may already be patched or has changed.")

except Exception as e:
    print(f"An error occurred: {e}")
    print("Please ensure the 'opennsfw2' library is installed correctly.")
# Out:
# Cloning into 'roop'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 61 (delta 14), reused 57 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (61/61), 3.24 MiB | 756.00 KiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/roop
# Cloning into 'BasicSR'...
# remote: Enumerating objects: 4680, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 4680 (delta 0), reused 0 (delta 0), pack-reused 4679 (from 1)
# Receiving objects: 100% (4680/4680), 3.98 MiB | 5.66 MiB/s, done.
# Resolving deltas: 100% (3114/3114), done.
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu128
# Ignoring torch: markers 'sys_platform == "win32"' don't match your environment
# Ignoring torchvision: markers 'sys_platform == "win32"' don't match your environment
# ...

# %% [markdown]
# **You will see processing message at the end of below printed messages e.g. Processing:  43% 136/318 00:38<00:24, 7.47frame/s**
#
# **Make sure to upload root roop folder not inside the sub roop folder and don't forget to change image and video file names**
#
# **1 is best quality big video size, 100 worst quality low video size**

# %%
# %cd "/content/roop"
# !python run.py -s "/content/face2.jpg" -t "/content/test_video.mp4" -o "/content/face_changed_video_v2.mp4" --keep-frames --keep-fps --temp-frame-quality 1 --output-video-quality 1 --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# /content/roop
# 2025-12-08 23:06:04.349747: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765235164.367663    7033 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765235164.373375    7033 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765235164.388180    7033 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# **Below code will do also face restoration to improve quality significantly but it will take longer**

# %%
# Pamiętaj, aby poprawić .png na .jpg, jeśli to konieczne!
# %cd "/content/roop"
# !python run.py -s "/content/face2.jpg" -t "/content/test_video.mp4" -o "/content/face_restored_video.mp4" --keep-frames --keep-fps --temp-frame-quality 1 --output-video-quality 1 --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# /content/roop
# 2025-12-08 23:16:45.005434: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765235805.027301    9821 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765235805.033017    9821 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765235805.047962    9821 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ### All options are displayed below
# Append any of them to the above commands before executing
# ```
# python run.py [options]
#
# -h, --help                                                                 show this help message and exit
# -s SOURCE_PATH, --source SOURCE_PATH                                       select an source image
# -t TARGET_PATH, --target TARGET_PATH                                       select an target image or video
# -o OUTPUT_PATH, --output OUTPUT_PATH                                       select output file or directory
# --frame-processor FRAME_PROCESSOR [FRAME_PROCESSOR ...]                    frame processors (choices: face_swapper, face_enhancer, ...)
# --keep-fps                                                                 keep target fps
# --keep-frames                                                              keep temporary frames
# --skip-audio                                                               skip target audio
# --many-faces                                                               process every face
# --reference-face-position REFERENCE_FACE_POSITION                          position of the reference face
# --reference-frame-number REFERENCE_FRAME_NUMBER                            number of the reference frame
# --similar-face-distance SIMILAR_FACE_DISTANCE                              face distance used for recognition
# --temp-frame-format {jpg,png}                                              image format used for frame extraction
# --temp-frame-quality [0-100]                                               image quality used for frame extraction
# --output-video-encoder {libx264,libx265,libvpx-vp9,h264_nvenc,hevc_nvenc}  encoder used for the output video
# --output-video-quality [0-100]                                             quality used for the output video
# --max-memory MAX_MEMORY                                                    maximum amount of RAM in GB
# --execution-provider {cpu} [{cpu} ...]                                     available execution provider (choices: cpu, ...)
# --execution-threads EXECUTION_THREADS                                      number of execution threads
# -v, --version                                                              show program's version number and exit
#   ```

# %% [markdown]
# ### Download generated images folder

# %%
import shutil
import os
from google.colab import files

def zip_directory(directory_path, zip_path):
    shutil.make_archive(zip_path, 'zip', directory_path)

# Set the directory path you want to download
directory_path = '/content/roop/video3'

# Set the zip file name
zip_filename = 'video3.zip'

# Zip the directory
zip_directory(directory_path, zip_filename)

# Download the zip file
files.download(zip_filename+'.zip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3934900988.py in <cell line: 0>()
#      13
#      14 # Zip the directory
# ---> 15 zip_directory(directory_path, zip_filename)
#      16
#      17 # Download the zip file
#
# /tmp/ipython-input-3934900988.py in zip_directory(directory_path, zip_path)
#       4
#       5 def zip_directory(directory_path, zip_path):
# ----> 6     shutil.make_archive(zip_path, 'zip', directory_path)
#       7
#       8 # Set the directory path you want to download
#
# /usr/lib/python3.12/shutil.py in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#    1142     save_cwd = None
#    1143     if root_dir is not None:
# -> 1144         stmd = os.stat(root_dir).st_mode
#    1145         if not stat.S_ISDIR(stmd):
# ...

# %%
#test case optional don't execute unless you are sure
# %cd "/content/roop"
# !wget https://huggingface.co/MonsterMMORPG/examples2/resolve/main/face2.png
# !wget https://huggingface.co/MonsterMMORPG/examples2/resolve/main/test_video.mp4
